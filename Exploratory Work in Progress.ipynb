# %%
from keras.utils import get_file

file_name = 'enwiki-20180920-pages-meta-current2.xml-p30304p88444.bz2'
file = get_file(file_name, 
         f'https://dumps.wikimedia.org/enwiki/20180920/{file_name}')
# Out:
# ...
# 237568000/237561410 [==============================] - 115s 0us/step

# %%
lines = []

import subprocess
import json

for i, l in enumerate(subprocess.Popen(['bzcat'], stdin = open(file), 
                          stdout = subprocess.PIPE).stdout):
    lines.append(l)
    if i > 1e6:
        break

# %%
lines[:20]
# Out:
# [b'<mediawiki xmlns="http://www.mediawiki.org/xml/export-0.10/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" version="0.10" xml:lang="en">\n',
#  b'  <siteinfo>\n',
#  b'    <sitename>Wikipedia</sitename>\n',
#  b'    <dbname>enwiki</dbname>\n',
#  b'    <base>https://en.wikipedia.org/wiki/Main_Page</base>\n',
#  b'    <generator>MediaWiki 1.32.0-wmf.20</generator>\n',
#  b'    <case>first-letter</case>\n',
#  b'    <namespaces>\n',
#  b'      <namespace key="-2" case="first-letter">Media</namespace>\n',
#  b'      <namespace key="-1" case="first-letter">Special</namespace>\n',
#  b'      <namespace key="0" case="first-letter" />\n',
#  b'      <namespace key="1" case="first-letter">Talk</namespace>\n',
#  b'      <namespace key="2" case="first-letter">User</namespace>\n',
#  b'      <namespace key="3" case="first-letter">User talk</namespace>\n',
# ...

# %%
lines[:20000]
# Out:
# [b'<feed>\n',
#  b'<doc>\n',
#  b'<title>Wikipedia: Anarchism</title>\n',
#  b'<url>https://en.wikipedia.org/wiki/Anarchism</url>\n',
#  b'<abstract>Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies,"In a society developed on these lines, the voluntary associations which already now begin to cover all the fields of human activity would take a still greater extension so as to substitute themselves for the state in all its functions.</abstract>\n',
#  b'<links>\n',
#  b'<sublink linktype="nav"><anchor>Etymology and terminology</anchor><link>https://en.wikipedia.org/wiki/Anarchism#Etymology_and_terminology</link></sublink>\n',
#  b'<sublink linktype="nav"><anchor>History</anchor><link>https://en.wikipedia.org/wiki/Anarchism#History</link></sublink>\n',
#  b'<sublink linktype="nav"><anchor>Origins</anchor><link>https://en.wikipedia.org/wiki/Anarchism#Origins</link></sublink>\n',
# ...

# %%
file_name = 'enwiki-20180901-abstract.xml.gz'
file = get_file(file_name, 
         f'https://dumps.wikimedia.org/enwiki/20180901/{file_name}')

lines = []
for i, l in enumerate(subprocess.Popen(['zcat'], stdin = open(file), 
                          stdout = subprocess.PIPE).stdout):
    lines.append(l)
    if i > 1e6:
        break
# Out:
# ...
# 717316096/717309912 [==============================] - 354s 0us/step

# %%
lines[:100]
# Out:
# [b'<feed>\n',
#  b'<doc>\n',
#  b'<title>Wikipedia: Anarchism</title>\n',
#  b'<url>https://en.wikipedia.org/wiki/Anarchism</url>\n',
#  b'<abstract>Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies,"In a society developed on these lines, the voluntary associations which already now begin to cover all the fields of human activity would take a still greater extension so as to substitute themselves for the state in all its functions.</abstract>\n',
#  b'<links>\n',
#  b'<sublink linktype="nav"><anchor>Etymology and terminology</anchor><link>https://en.wikipedia.org/wiki/Anarchism#Etymology_and_terminology</link></sublink>\n',
#  b'<sublink linktype="nav"><anchor>History</anchor><link>https://en.wikipedia.org/wiki/Anarchism#History</link></sublink>\n',
#  b'<sublink linktype="nav"><anchor>Origins</anchor><link>https://en.wikipedia.org/wiki/Anarchism#Origins</link></sublink>\n',
# ...
